# %%
import pandas as pd
import gzip
import json
import numpy as np

# %% [markdown]
# # LabWork

# %%
# file_path_r = "../data/raw/Electronics.jsonl.gz"
# file_path_m = "../data/raw/meta_Electronics.jsonl.gz"

# n_rows = 2000

# reviews = []

# with gzip.open(file_path_r, "rt") as f:

#     for i, line in enumerate(f):
#         if i >= n_rows:
#             break
#         reviews.append(json.loads(line))

# meta = []
# with gzip.open(file_path_m, "rt") as f:

#     for i, line in enumerate(f):
#         if i >= n_rows:
#             break
#         meta.append(json.loads(line))


# review_df = pd.DataFrame(reviews)
# meta = pd.DataFrame(meta)

# %%
# review_df.head()
# KEY: parent_asin
# core: title (descriptor), helpful_vote,
# nice to have: rating, text (cluttered/explode)
# no:  images, asin, user_id, timestamp, verified_purchase(not for query view), helpful_vote
# Out:
#    rating                                        title  \
# 0     3.0            Smells like gasoline! Going back!
# 1     1.0      Didn’t work at all lenses loose/broken.
# 2     5.0                                   Excellent!
# 3     5.0                       Great laptop backpack!
# 4     5.0  Best Headphones in the Fifties price range!
#
#                                                 text  \
# 0  First & most offensive: they reek of gasoline ...
# 1  These didn’t work. Idk if they were damaged in...
# 2  I love these. They even come with a carry case...
# 3  I was searching for a sturdy backpack for scho...
# 4  I've bought these headphones three times becau...
#
#                                               images        asin parent_asin  \
# 0  [{'small_image_url': 'https://m.media-amazon.c...  B083NRGZMM  B083NRGZMM
# 1                                                 []  B07N69T6TM  B07N69T6TM
# ...

# %%
# meta.head(10)
# KEY: parent_asin
# at min: main_category, title, features, description, details
# nice to haves: rating_number, average_rating, price, store 
# no: images, videos, subtitle, author, bought_together(empty)
# Out:
#                main_category  \
# 0            All Electronics
# 1            All Electronics
# 2                  Computers
# 3             AMAZON FASHION
# 4  Cell Phones & Accessories
# 5          Sports & Outdoors
# 6  Cell Phones & Accessories
# 7    Industrial & Scientific
# 8                  Computers
# 9                       None
#
#                                                title  average_rating  \
# 0             FS-1051 FATSHARK TELEPORTER V3 HEADSET             3.5
# 1                      Ce-H22B12-S1 4Kx2K Hdmi 4Port             5.0
# 2  Digi-Tatoo Decal Skin Compatible With MacBook ...             4.5
# 3  NotoCity Compatible with Vivoactive 4 band 22m...             4.5
# 4             Motorola Droid X Essentials Combo Pack             3.8
# 5  Raymarine Wi-Fish DownVision Blackbox Sonar wi...             3.5
# 6  QGHXO Band for Garmin Vivofit 4, Soft Silicone...             4.4
# 7  Protech iPhone 4 microscope 60X Lens with illu...             3.8
# ...

# %%
# meta = meta.replace({None: np.nan})
# meta["bought_together"]
# meta[meta["bought_together"].notnull()]
# Out:
# Empty DataFrame
# Columns: [main_category, title, average_rating, rating_number, features, description, price, images, videos, store, categories, details, parent_asin, bought_together, subtitle, author]
# Index: []

# %%
# meta["bought_together"].unique()
# Out:
# array([nan])

# %%
hard_drop = ["images", "videos", "subtitle", "author", "bought_together"]
nice_but_drop = ["rating_number", "average_rating", "price", "store"]
full_drop = hard_drop + nice_but_drop
meta_subset = meta.drop(columns= full_drop)

# %%
meta_subset.to_csv("../data/processed/meta_subset.csv",index=False)

# %% [markdown]
# # EDA stuff

# %% [markdown]
# ** N OTE TO CHECK THE "DETAILS" col which might be a dictonary? How do we want to handel that?

# %% [markdown]
# 1) check how the files are in isolation
#
# 2) maybe can do some extra thing for the merged sample version?  (honestly optional)
